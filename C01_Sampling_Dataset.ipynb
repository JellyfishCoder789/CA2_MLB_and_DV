# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pse_isr_reddit_comments.csv')

# %%
df['created_date'] = pd.to_datetime(df['created_time']).dt.date

# %%
df.head()
# Out:
#   comment_id  score                                          self_text  \
# 0    k9p5rvg      1  I have no problem with everything you said, ju...
# 1    k9p5p4i      1                   Could you provide sources please
# 2    k9p5orp      1  I have a problem with talk about ethnic cleans...
# 3    k9p5mff      1  There is a multitude of war crimes committed a...
# 4    k9p5lh5      1  [https://www.crownprince.bh/en/contact](https:...
#
#          subreddit               created_time created_date
# 0  IsraelPalestine  2023-11-17 23:03:25+00:00   2023-11-17
# 1  IsraelPalestine  2023-11-17 23:02:51+00:00   2023-11-17
# 2  IsraelPalestine  2023-11-17 23:02:47+00:00   2023-11-17
# 3  IsraelPalestine  2023-11-17 23:02:17+00:00   2023-11-17
# 4        worldnews  2023-11-17 23:02:06+00:00   2023-11-17

# %%
df.shape
# Out:
# (755469, 6)

# %% [markdown]
# ##### Dropping comments from before the Hamas attack
#  There are only 7 comments in the dataset from before the attack, and so they are removed, as there is not enough data to make assumptions based on these 7 comments.

# %%
data_to_drop = df[df['created_date'] == pd.to_datetime("2023-10-06").date()].index

df = df.drop(data_to_drop)

# %%
sampling_ratio = 0.1  # 10%

reduced_df = df.groupby('created_date').apply(lambda x: x.sample(frac = sampling_ratio)).reset_index(drop = True)

# %%
reduced_df.shape
# Out:
# (75543, 6)

# %%
reduced_df.head(30)
# Out:
#    comment_id  score                                          self_text  \
# 0     k3v7osg      1                           We've got enough angles.
# 1     k3u4gwf    793                     its a holiday there right now.
# 2     k3vct71    -27                                  Good Job Israel 💪
# 3     k3ucisf     47  Especially when the start of that whole ass wa...
# 4     k3veo8m     18  I remember when the US and Israel made a parad...
# 5     k3tovx0     78  A great victory well done to our Palestinian b...
# 6     k3u4kzq     14  Depend on how much Netanyahu able to exploit t...
# 7     k3vsoj1    138  And to roll back some of the normalization tha...
# 8     k3w6eyc     63  As long as Hamas exists, there can't be peace....
# 9     k3vfupu     -2  Bbb..bbb ..b... but there's no proof of killin...
# 10    k3x0fed      3  This will never end. It may quite down for a w...
# 11    k3v16ww    400         I guess that is the end if the Gaza strip.
# 12    k3woy8t     -1  How about you think about all the innocents on...
# 13    k3uq4bm     55  Hamas aren’t stupid, they know exactly what th...
# 14    k3x3fvv      1  Not so much targets, but definitely not suffic...
# 15    k3v2d6a      7            Bro it's been decades it's a lost cause
# 16    k3upymt     13  Is swear first thing that came to mind is the ...
# 17    k3wchoq      3           Wasn't hamas voted in by the population?
# 18    k3u30ur     -3  Israel is literally gobbling up internationall...
# 19    k3vh6k4     15  They want the israeli-saudi deal to fall throu...
# 20    k3wjasi      1                     Such a great day for the world
